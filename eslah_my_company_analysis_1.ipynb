# %% [markdown]
# <a href="https://colab.research.google.com/github/arezookhalilinasr22/nlp/blob/main/eslah_my_company_analysis_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_excel('/content/book4.xlsx')
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df.head()
# Out:
#     article                                            name type_promotion_1  \
# 0  10001881                             بستني بيسکورول ميهن           koolak
# 1  10001874                         دوغ ساده  1500گرمی میهن           koolak
# 2  10001869                        دوغ نعناع  1500گرمی میهن           koolak
# 3  10003939  پنير سفيد نسبتا چرب ايراني دی 3 400 گرمي  میهن           koolak
# 4  10005607              ماست یونانی کم چرب 1500 گرم می ماس           koolak
#
#    discount_koolak_1  Sale_NO_1   Sale_RR_1  Margin_1  Gross_Profit_1  \
# 0               0.10      10668  1318292579  0.191468    2.524113e+08
# 1               0.20       2808   660678779  0.198533    1.311664e+08
# 2               0.20       5179  1176929921  0.192246    2.262597e+08
# 3               0.12       8362  3346560800  0.213614    7.148727e+08
# 4               0.20        290   255465000  0.211216    5.395838e+07
#
#   type_promotion_2  discount_jarchi_2  ...  Margin_4  Gross_Profit_4  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 34 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   article            36 non-null     int64
#  1   name               36 non-null     object
#  2   type_promotion_1   36 non-null     object
#  3   discount_koolak_1  36 non-null     float64
#  4   Sale_NO_1          36 non-null     int64
#  5   Sale_RR_1          36 non-null     int64
#  6   Margin_1           36 non-null     float64
#  7   Gross_Profit_1     36 non-null     float64
#  8   type_promotion_2   36 non-null     object
#  9   discount_jarchi_2  36 non-null     float64
#  10  Sale_NO_2          36 non-null     int64
#  11  Sale_RR_2          36 non-null     int64
#  12  Margin_2           36 non-null     float64
#  13  Gross_Profit_2     36 non-null     float64
#  14  type_promotion_3   36 non-null     object
#  15  discount_jarchi_3  36 non-null     float64
# ...

# %%
df.shape
# Out:
# (36, 34)

# %%
df
# Out:
#      article                                            name type_promotion_1  \
# 0   10001881                             بستني بيسکورول ميهن           koolak
# 1   10001874                         دوغ ساده  1500گرمی میهن           koolak
# 2   10001869                        دوغ نعناع  1500گرمی میهن           koolak
# 3   10003939  پنير سفيد نسبتا چرب ايراني دی 3 400 گرمي  میهن           koolak
# 4   10005607              ماست یونانی کم چرب 1500 گرم می ماس           koolak
# 5   10005610                         پنیر یواف 400 گرمی صباح           koolak
# 6   10003113                              کارنیتا وانیل میهن           koolak
# 7   10001883                        بستني کارنيتا شکلات ميهن           koolak
# 8   10001863                      شیر کاکائو  200 سی سی میهن           koolak
# 9   10004219                           پنیر گاو خندان روزانه           koolak
# 10  10001886                       ماست 500 گرم پرچرب می ماس           koolak
# ...

# %%
df.columns
# Out:
# Index(['article', 'name', 'type_promotion_1', 'discount_koolak_1', 'Sale_NO_1',
#        'Sale_RR_1', 'Margin_1', 'Gross_Profit_1', 'type_promotion_2',
#        'discount_jarchi_2', 'Sale_NO_2', 'Sale_RR_2', 'Margin_2',
#        'Gross_Profit_2', 'type_promotion_3', 'discount_jarchi_3', 'Sale_No_3',
#        'Sale_RR_3', 'Margin_3', 'Gross_Profit_3', 'type_promotion_4',
#        'discount_jarchi_4', 'Sale_NO_4', 'Sale_RR_4', 'Margin_4',
#        'Gross_Profit_4', 'koolak_1_hafte', 'koolak_1_month', 'jarchi_2_hafte',
#        'jarchi_2_month', 'jarchi_3_hafte', 'jarchi_3_month', 'jarchi_4_hafte',
#        'jarchi_4_month'],
#       dtype='object')

# %%
df2=df.nsmallest(36,['Gross_Profit_1'])
print(df2)
# Out:
#      article                                            name type_promotion_1  \
# 10  10001886                       ماست 500 گرم پرچرب می ماس           koolak
# 20  10006126              ماست یونانی پر چرب 1500 گرم می ماس           koolak
# 32  10000632                      کرم کنجد ساده 350 گرم عقاب           koolak
# 4   10005607              ماست یونانی کم چرب 1500 گرم می ماس           koolak
# 34  10007174                              ارده 600 گرمی عقاب           koolak
# 12  10001337      ماكاروني فرمی پروانه اي   500 گ زر ماكارون           koolak
# 35  10003636                   ماست سبو پرچرب 1800 گرمی هراز           koolak
# 11  10001844                 شير كم چرب ساده  200 سي سي میهن           koolak
# 33  10002966                   دوغ  سنتی1/5 لیتری  پونه هراز           koolak
# 13  10006130                     شیر کم چرب 200 سی سی روزانه           koolak
# 30  10001320                     اسپاگتي  500 گرم زر ماكارون           koolak
# ...

# %%
df5=df.nsmallest(3,['Gross_Profit_1','Gross_Profit_2','Gross_Profit_3','Gross_Profit_4'])
print(df5)
# Out:
#      article                                name type_promotion_1  \
# 10  10001886           ماست 500 گرم پرچرب می ماس           koolak
# 20  10006126  ماست یونانی پر چرب 1500 گرم می ماس           koolak
# 32  10000632          کرم کنجد ساده 350 گرم عقاب           koolak
#
#     discount_koolak_1  Sale_NO_1  Sale_RR_1  Margin_1  Gross_Profit_1  \
# 10               0.20        605  121046000  0.212742      25751550.0
# 20               0.27        283  227591000  0.136569      31081772.0
# 32               0.12        685  586443985  0.075636      44356349.0
#
#    type_promotion_2  discount_jarchi_2  ...  Margin_4  Gross_Profit_4  \
# 10           Jarchi                0.2  ...  0.126520      16085464.0
# 20           Jarchi                0.2  ...  0.113987      19679282.0
# 32           Jarchi                0.2  ...  0.075620      57854056.0
#
#     koolak_1_hafte  koolak_1_month jarchi_2_hafte  jarchi_2_month  \
# ...

# %%
#df4 = df['name'].groupby(['Gross_Profit_1','Gross_Profit_2','Gross_Profit_3','Gross_Profit_4']).max()
#ino badan bayad roosh kar knm ke chera in error ro mde

# %%
df25=df.nlargest(36,['Gross_Profit_1'])
df25
# Out:
#      article                                            name type_promotion_1  \
# 22  10000791                نوشابه کولا 1500 cc پت کوکا کولا           koolak
# 3   10003939  پنير سفيد نسبتا چرب ايراني دی 3 400 گرمي  میهن           koolak
# 23  10000802                 نوشابه پرتقالی 1500 cc پت فانتا           koolak
# 24  10000807                نوشابه لیمویی 1500 cc پت اسپرایت           koolak
# 5   10005610                         پنیر یواف 400 گرمی صباح           koolak
# 27  10005501                       پنیر لاکتیکی 300 گرم صباح           koolak
# 14  10001893        پنير نسبتا چرب (طرح جديد)روزانه 515 گرمي           koolak
# 17  10001872                         بستني عروسكي(ميرکس)ميهن           koolak
# 19  10001321                 اسپاگتي 1/5  700 گرم زر ماكارون           koolak
# 15  10001894        پنير نسبتا چرب (طرح جديد)روزانه 210 گرمي           koolak
# 26  10001834            شیر  ساده پرچرب اسکوئر 1000گرمی میهن           koolak
# ...

# %%
df6=df.nlargest(36,['Gross_Profit_1','Gross_Profit_2','Gross_Profit_3','Gross_Profit_4'])
print(df6)
# Out:
#      article                                            name type_promotion_1  \
# 22  10000791                نوشابه کولا 1500 cc پت کوکا کولا           koolak
# 3   10003939  پنير سفيد نسبتا چرب ايراني دی 3 400 گرمي  میهن           koolak
# 23  10000802                 نوشابه پرتقالی 1500 cc پت فانتا           koolak
# 24  10000807                نوشابه لیمویی 1500 cc پت اسپرایت           koolak
# 5   10005610                         پنیر یواف 400 گرمی صباح           koolak
# 27  10005501                       پنیر لاکتیکی 300 گرم صباح           koolak
# 14  10001893        پنير نسبتا چرب (طرح جديد)روزانه 515 گرمي           koolak
# 17  10001872                         بستني عروسكي(ميرکس)ميهن           koolak
# 19  10001321                 اسپاگتي 1/5  700 گرم زر ماكارون           koolak
# 15  10001894        پنير نسبتا چرب (طرح جديد)روزانه 210 گرمي           koolak
# 26  10001834            شیر  ساده پرچرب اسکوئر 1000گرمی میهن           koolak
# ...

# %%
df7=df.nlargest(36,['Gross_Profit_1','Gross_Profit_2','Gross_Profit_3','Gross_Profit_4','koolak_1_hafte','jarchi_2_hafte','jarchi_3_hafte','jarchi_4_hafte'])
print(df7)
# Out:
#      article                                            name type_promotion_1  \
# 22  10000791                نوشابه کولا 1500 cc پت کوکا کولا           koolak
# 3   10003939  پنير سفيد نسبتا چرب ايراني دی 3 400 گرمي  میهن           koolak
# 23  10000802                 نوشابه پرتقالی 1500 cc پت فانتا           koolak
# 24  10000807                نوشابه لیمویی 1500 cc پت اسپرایت           koolak
# 5   10005610                         پنیر یواف 400 گرمی صباح           koolak
# 27  10005501                       پنیر لاکتیکی 300 گرم صباح           koolak
# 14  10001893        پنير نسبتا چرب (طرح جديد)روزانه 515 گرمي           koolak
# 17  10001872                         بستني عروسكي(ميرکس)ميهن           koolak
# 19  10001321                 اسپاگتي 1/5  700 گرم زر ماكارون           koolak
# 15  10001894        پنير نسبتا چرب (طرح جديد)روزانه 210 گرمي           koolak
# 26  10001834            شیر  ساده پرچرب اسکوئر 1000گرمی میهن           koolak
# ...

# %%
df8=df.nlargest(36,['Gross_Profit_1','Gross_Profit_2','Gross_Profit_3','Gross_Profit_4','koolak_1_hafte','jarchi_2_hafte','jarchi_3_hafte','jarchi_4_hafte','koolak_1_month','jarchi_2_month','jarchi_3_month','jarchi_4_month'])
print(df8)
# Out:
#      article                                            name type_promotion_1  \
# 22  10000791                نوشابه کولا 1500 cc پت کوکا کولا           koolak
# 3   10003939  پنير سفيد نسبتا چرب ايراني دی 3 400 گرمي  میهن           koolak
# 23  10000802                 نوشابه پرتقالی 1500 cc پت فانتا           koolak
# 24  10000807                نوشابه لیمویی 1500 cc پت اسپرایت           koolak
# 5   10005610                         پنیر یواف 400 گرمی صباح           koolak
# 27  10005501                       پنیر لاکتیکی 300 گرم صباح           koolak
# 14  10001893        پنير نسبتا چرب (طرح جديد)روزانه 515 گرمي           koolak
# 17  10001872                         بستني عروسكي(ميرکس)ميهن           koolak
# 19  10001321                 اسپاگتي 1/5  700 گرم زر ماكارون           koolak
# 15  10001894        پنير نسبتا چرب (طرح جديد)روزانه 210 گرمي           koolak
# 26  10001834            شیر  ساده پرچرب اسکوئر 1000گرمی میهن           koolak
# ...

# %%
df8
# Out:
#      article                                            name type_promotion_1  \
# 22  10000791                نوشابه کولا 1500 cc پت کوکا کولا           koolak
# 3   10003939  پنير سفيد نسبتا چرب ايراني دی 3 400 گرمي  میهن           koolak
# 23  10000802                 نوشابه پرتقالی 1500 cc پت فانتا           koolak
# 24  10000807                نوشابه لیمویی 1500 cc پت اسپرایت           koolak
# 5   10005610                         پنیر یواف 400 گرمی صباح           koolak
# 27  10005501                       پنیر لاکتیکی 300 گرم صباح           koolak
# 14  10001893        پنير نسبتا چرب (طرح جديد)روزانه 515 گرمي           koolak
# 17  10001872                         بستني عروسكي(ميرکس)ميهن           koolak
# 19  10001321                 اسپاگتي 1/5  700 گرم زر ماكارون           koolak
# 15  10001894        پنير نسبتا چرب (طرح جديد)روزانه 210 گرمي           koolak
# 26  10001834            شیر  ساده پرچرب اسکوئر 1000گرمی میهن           koolak
# ...

# %%
df9=df.nsmallest(3,['Gross_Profit_1','Gross_Profit_2','Gross_Profit_3','Gross_Profit_4','koolak_1_hafte','jarchi_2_hafte','jarchi_3_hafte','jarchi_4_hafte','koolak_1_month','jarchi_2_month','jarchi_3_month','jarchi_4_month'])
print(df9)
# Out:
#      article                                name type_promotion_1  \
# 10  10001886           ماست 500 گرم پرچرب می ماس           koolak
# 20  10006126  ماست یونانی پر چرب 1500 گرم می ماس           koolak
# 32  10000632          کرم کنجد ساده 350 گرم عقاب           koolak
#
#     discount_koolak_1  Sale_NO_1  Sale_RR_1  Margin_1  Gross_Profit_1  \
# 10               0.20        605  121046000  0.212742      25751550.0
# 20               0.27        283  227591000  0.136569      31081772.0
# 32               0.12        685  586443985  0.075636      44356349.0
#
#    type_promotion_2  discount_jarchi_2  ...  Margin_4  Gross_Profit_4  \
# 10           Jarchi                0.2  ...  0.126520      16085464.0
# 20           Jarchi                0.2  ...  0.113987      19679282.0
# 32           Jarchi                0.2  ...  0.075620      57854056.0
#
#     koolak_1_hafte  koolak_1_month jarchi_2_hafte  jarchi_2_month  \
# ...

# %%
df9
# Out:
#      article                                name type_promotion_1  \
# 10  10001886           ماست 500 گرم پرچرب می ماس           koolak
# 20  10006126  ماست یونانی پر چرب 1500 گرم می ماس           koolak
# 32  10000632          کرم کنجد ساده 350 گرم عقاب           koolak
#
#     discount_koolak_1  Sale_NO_1  Sale_RR_1  Margin_1  Gross_Profit_1  \
# 10               0.20        605  121046000  0.212742      25751550.0
# 20               0.27        283  227591000  0.136569      31081772.0
# 32               0.12        685  586443985  0.075636      44356349.0
#
#    type_promotion_2  discount_jarchi_2  ...  Margin_4  Gross_Profit_4  \
# 10           Jarchi                0.2  ...  0.126520      16085464.0
# 20           Jarchi                0.2  ...  0.113987      19679282.0
# 32           Jarchi                0.2  ...  0.075620      57854056.0
#
#     koolak_1_hafte  koolak_1_month jarchi_2_hafte  jarchi_2_month  \
# ...

# %%
groups = df.groupby(['name','discount_koolak_1','discount_jarchi_2','discount_jarchi_3','discount_jarchi_4','type_promotion_1','type_promotion_2','type_promotion_3','type_promotion_4'])

# %%
groups

# %%
groups.aggregate('max')
# Out:
#                                                                                                                                                                                              article  \
# name                                           discount_koolak_1 discount_jarchi_2 discount_jarchi_3 discount_jarchi_4 type_promotion_1 type_promotion_2 type_promotion_3 type_promotion_4
# ارده 600 گرمی عقاب                             0.120             0.200             0.200             0.200             koolak           Jarchi           Jarchi           Jarchi            10007174
# اسپاگتي  500 گرم زر ماكارون                    0.200             0.120             0.100             0.100             koolak           Jarchi           Jarchi           Jarchi            10001320
# اسپاگتي 1/2  500 گرم زرماكارون                 0.100             0.120             0.150             0.100             koolak           Jarchi           Jarchi           Jarchi            10001318
# ...

# %%
#groups.aggregate({'Salary': 'sum', 'Years of Experience': 'mean'})

# %%
x = groups.aggregate({'Gross_Profit_1': 'max', 'Gross_Profit_2': 'max','Gross_Profit_3':'max','Gross_Profit_4': 'max','koolak_1_hafte' : 'max','jarchi_2_hafte': 'max','jarchi_3_hafte':'max','jarchi_4_hafte': 'max','koolak_1_month': 'max','jarchi_2_month':'max','jarchi_3_month':'max','jarchi_4_month':'max'})

# %%
x.sort_values(by=['Gross_Profit_1'])
# Out:
#                                                                                                                                                                                             Gross_Profit_1  \
# name                                           discount_koolak_1 discount_jarchi_2 discount_jarchi_3 discount_jarchi_4 type_promotion_1 type_promotion_2 type_promotion_3 type_promotion_4
# ماست 500 گرم پرچرب می ماس                      0.200             0.200             0.220             0.250             koolak           Jarchi           Jarchi           Jarchi              2.575155e+07
# ماست یونانی پر چرب 1500 گرم می ماس             0.270             0.200             0.250             0.270             koolak           Jarchi           Jarchi           Jarchi              3.108177e+07
# ...

# %%
x.sort_values(by=['Gross_Profit_1','Gross_Profit_2','Gross_Profit_3','Gross_Profit_4'])
# Out:
#                                                                                                                                                                                             Gross_Profit_1  \
# name                                           discount_koolak_1 discount_jarchi_2 discount_jarchi_3 discount_jarchi_4 type_promotion_1 type_promotion_2 type_promotion_3 type_promotion_4
# ماست 500 گرم پرچرب می ماس                      0.200             0.200             0.220             0.250             koolak           Jarchi           Jarchi           Jarchi              2.575155e+07
# ماست یونانی پر چرب 1500 گرم می ماس             0.270             0.200             0.250             0.270             koolak           Jarchi           Jarchi           Jarchi              3.108177e+07
# ...

# %%
x.sort_values(by=['Gross_Profit_1','Gross_Profit_2','Gross_Profit_3','Gross_Profit_4','koolak_1_hafte','jarchi_2_hafte','jarchi_3_hafte','jarchi_4_hafte'])
# Out:
#                                                                                                                                                                                             Gross_Profit_1  \
# name                                           discount_koolak_1 discount_jarchi_2 discount_jarchi_3 discount_jarchi_4 type_promotion_1 type_promotion_2 type_promotion_3 type_promotion_4
# ماست 500 گرم پرچرب می ماس                      0.200             0.200             0.220             0.250             koolak           Jarchi           Jarchi           Jarchi              2.575155e+07
# ماست یونانی پر چرب 1500 گرم می ماس             0.270             0.200             0.250             0.270             koolak           Jarchi           Jarchi           Jarchi              3.108177e+07
# ...

# %%
x.sort_values(by=['Gross_Profit_1','Gross_Profit_2','Gross_Profit_3','Gross_Profit_4','koolak_1_hafte','jarchi_2_hafte','jarchi_3_hafte','jarchi_4_hafte','koolak_1_month','jarchi_2_month','jarchi_3_month','jarchi_4_month'])
# Out:
#                                                                                                                                                                                             Gross_Profit_1  \
# name                                           discount_koolak_1 discount_jarchi_2 discount_jarchi_3 discount_jarchi_4 type_promotion_1 type_promotion_2 type_promotion_3 type_promotion_4
# ماست 500 گرم پرچرب می ماس                      0.200             0.200             0.220             0.250             koolak           Jarchi           Jarchi           Jarchi              2.575155e+07
# ماست یونانی پر چرب 1500 گرم می ماس             0.270             0.200             0.250             0.270             koolak           Jarchi           Jarchi           Jarchi              3.108177e+07
# ...

# %%
#### From this analysis, we come to the conclusion that the discounted
###goods should be based on the name from top to bottom because the maximum
##gross profit and the maximum growth percentage indifferent intervals were
#obtained based on this analysis.

# %%
y = groups.aggregate({'Gross_Profit_1': 'max', 'Gross_Profit_2': 'max','Gross_Profit_3':'max','Gross_Profit_4': 'max'})

# %%
y.sort_values(by=['Gross_Profit_1','Gross_Profit_2','Gross_Profit_3','Gross_Profit_4'])
# Out:
#                                                                                                                                                                                             Gross_Profit_1  \
# name                                           discount_koolak_1 discount_jarchi_2 discount_jarchi_3 discount_jarchi_4 type_promotion_1 type_promotion_2 type_promotion_3 type_promotion_4
# ماست 500 گرم پرچرب می ماس                      0.200             0.200             0.220             0.250             koolak           Jarchi           Jarchi           Jarchi              2.575155e+07
# ماست یونانی پر چرب 1500 گرم می ماس             0.270             0.200             0.250             0.270             koolak           Jarchi           Jarchi           Jarchi              3.108177e+07
# ...

# %%
df['Length_Range'] = len(range(1, 37))

# %%
sorted_df1 = df.sort_values(by='Gross_Profit_1', ascending=True)

# %%
sorted_df1
# Out:
#      article                                            name type_promotion_1  \
# 10  10001886                       ماست 500 گرم پرچرب می ماس           koolak
# 20  10006126              ماست یونانی پر چرب 1500 گرم می ماس           koolak
# 32  10000632                      کرم کنجد ساده 350 گرم عقاب           koolak
# 4   10005607              ماست یونانی کم چرب 1500 گرم می ماس           koolak
# 34  10007174                              ارده 600 گرمی عقاب           koolak
# 12  10001337      ماكاروني فرمی پروانه اي   500 گ زر ماكارون           koolak
# 35  10003636                   ماست سبو پرچرب 1800 گرمی هراز           koolak
# 11  10001844                 شير كم چرب ساده  200 سي سي میهن           koolak
# 33  10002966                   دوغ  سنتی1/5 لیتری  پونه هراز           koolak
# 13  10006130                     شیر کم چرب 200 سی سی روزانه           koolak
# 30  10001320                     اسپاگتي  500 گرم زر ماكارون           koolak
# ...

# %%
sorted_df2 = df.sort_values(by=['Gross_Profit_1', 'Gross_Profit_2'], ascending=True)

# %%
sorted_df2
# Out:
#      article                                            name type_promotion_1  \
# 10  10001886                       ماست 500 گرم پرچرب می ماس           koolak
# 20  10006126              ماست یونانی پر چرب 1500 گرم می ماس           koolak
# 32  10000632                      کرم کنجد ساده 350 گرم عقاب           koolak
# 4   10005607              ماست یونانی کم چرب 1500 گرم می ماس           koolak
# 34  10007174                              ارده 600 گرمی عقاب           koolak
# 12  10001337      ماكاروني فرمی پروانه اي   500 گ زر ماكارون           koolak
# 35  10003636                   ماست سبو پرچرب 1800 گرمی هراز           koolak
# 11  10001844                 شير كم چرب ساده  200 سي سي میهن           koolak
# 33  10002966                   دوغ  سنتی1/5 لیتری  پونه هراز           koolak
# 13  10006130                     شیر کم چرب 200 سی سی روزانه           koolak
# 30  10001320                     اسپاگتي  500 گرم زر ماكارون           koolak
# ...

# %%
sorted_df3 = df.sort_values(by=['Gross_Profit_1', 'Gross_Profit_2','Gross_Profit_3'], ascending=True)

# %%
sorted_df3
# Out:
#      article                                            name type_promotion_1  \
# 10  10001886                       ماست 500 گرم پرچرب می ماس           koolak
# 20  10006126              ماست یونانی پر چرب 1500 گرم می ماس           koolak
# 32  10000632                      کرم کنجد ساده 350 گرم عقاب           koolak
# 4   10005607              ماست یونانی کم چرب 1500 گرم می ماس           koolak
# 34  10007174                              ارده 600 گرمی عقاب           koolak
# 12  10001337      ماكاروني فرمی پروانه اي   500 گ زر ماكارون           koolak
# 35  10003636                   ماست سبو پرچرب 1800 گرمی هراز           koolak
# 11  10001844                 شير كم چرب ساده  200 سي سي میهن           koolak
# 33  10002966                   دوغ  سنتی1/5 لیتری  پونه هراز           koolak
# 13  10006130                     شیر کم چرب 200 سی سی روزانه           koolak
# 30  10001320                     اسپاگتي  500 گرم زر ماكارون           koolak
# ...

# %%
sorted_df4 = df.sort_values(by=['Gross_Profit_1', 'Gross_Profit_2','Gross_Profit_3','Gross_Profit_4'], ascending=False)
sorted_df4
# Out:
#      article                                            name type_promotion_1  \
# 22  10000791                نوشابه کولا 1500 cc پت کوکا کولا           koolak
# 3   10003939  پنير سفيد نسبتا چرب ايراني دی 3 400 گرمي  میهن           koolak
# 23  10000802                 نوشابه پرتقالی 1500 cc پت فانتا           koolak
# 24  10000807                نوشابه لیمویی 1500 cc پت اسپرایت           koolak
# 5   10005610                         پنیر یواف 400 گرمی صباح           koolak
# 27  10005501                       پنیر لاکتیکی 300 گرم صباح           koolak
# 14  10001893        پنير نسبتا چرب (طرح جديد)روزانه 515 گرمي           koolak
# 17  10001872                         بستني عروسكي(ميرکس)ميهن           koolak
# 19  10001321                 اسپاگتي 1/5  700 گرم زر ماكارون           koolak
# 15  10001894        پنير نسبتا چرب (طرح جديد)روزانه 210 گرمي           koolak
# 26  10001834            شیر  ساده پرچرب اسکوئر 1000گرمی میهن           koolak
# ...

# %%
import pandas as pd

# فرض کنید df داده‌فریم شما باشد

# انجام مرتب‌سازی بر اساس چهار ستون 'Gross_Profit_1' تا 'Gross_Profit_4'
sorted_df5 = df.sort_values(by=['Gross_Profit_1', 'Gross_Profit_2', 'Gross_Profit_3', 'Gross_Profit_4'])

# افزودن ستون جدید به نام 'Total_Rank' با محاسبه جمع رتبه‌ها برای هر سطر
sorted_df5['Total_Rank'] = sorted_df5[['Gross_Profit_1', 'Gross_Profit_2', 'Gross_Profit_3', 'Gross_Profit_4']].sum(axis=1)

# نمایش نتیجه
print(sorted_df5)
# Out:
#      article                                            name type_promotion_1  \
# 10  10001886                       ماست 500 گرم پرچرب می ماس           koolak
# 20  10006126              ماست یونانی پر چرب 1500 گرم می ماس           koolak
# 32  10000632                      کرم کنجد ساده 350 گرم عقاب           koolak
# 4   10005607              ماست یونانی کم چرب 1500 گرم می ماس           koolak
# 34  10007174                              ارده 600 گرمی عقاب           koolak
# 12  10001337      ماكاروني فرمی پروانه اي   500 گ زر ماكارون           koolak
# 35  10003636                   ماست سبو پرچرب 1800 گرمی هراز           koolak
# 11  10001844                 شير كم چرب ساده  200 سي سي میهن           koolak
# 33  10002966                   دوغ  سنتی1/5 لیتری  پونه هراز           koolak
# 13  10006130                     شیر کم چرب 200 سی سی روزانه           koolak
# 30  10001320                     اسپاگتي  500 گرم زر ماكارون           koolak
# ...

# %%
#ba excel joor dar nemiad pas sotoon be sotoon ba excel check mknm

# %%
sorted_df6 = df.sort_values(by='Gross_Profit_1')
sorted_df6
# Out:
#      article                                            name type_promotion_1  \
# 10  10001886                       ماست 500 گرم پرچرب می ماس           koolak
# 20  10006126              ماست یونانی پر چرب 1500 گرم می ماس           koolak
# 32  10000632                      کرم کنجد ساده 350 گرم عقاب           koolak
# 4   10005607              ماست یونانی کم چرب 1500 گرم می ماس           koolak
# 34  10007174                              ارده 600 گرمی عقاب           koolak
# 12  10001337      ماكاروني فرمی پروانه اي   500 گ زر ماكارون           koolak
# 35  10003636                   ماست سبو پرچرب 1800 گرمی هراز           koolak
# 11  10001844                 شير كم چرب ساده  200 سي سي میهن           koolak
# 33  10002966                   دوغ  سنتی1/5 لیتری  پونه هراز           koolak
# 13  10006130                     شیر کم چرب 200 سی سی روزانه           koolak
# 30  10001320                     اسپاگتي  500 گرم زر ماكارون           koolak
# ...

# %%
sorted_df7 = df.sort_values(by=['Gross_Profit_1', 'Gross_Profit_2'])
sorted_df7
# Out:
#      article                                            name type_promotion_1  \
# 10  10001886                       ماست 500 گرم پرچرب می ماس           koolak
# 20  10006126              ماست یونانی پر چرب 1500 گرم می ماس           koolak
# 32  10000632                      کرم کنجد ساده 350 گرم عقاب           koolak
# 4   10005607              ماست یونانی کم چرب 1500 گرم می ماس           koolak
# 34  10007174                              ارده 600 گرمی عقاب           koolak
# 12  10001337      ماكاروني فرمی پروانه اي   500 گ زر ماكارون           koolak
# 35  10003636                   ماست سبو پرچرب 1800 گرمی هراز           koolak
# 11  10001844                 شير كم چرب ساده  200 سي سي میهن           koolak
# 33  10002966                   دوغ  سنتی1/5 لیتری  پونه هراز           koolak
# 13  10006130                     شیر کم چرب 200 سی سی روزانه           koolak
# 30  10001320                     اسپاگتي  500 گرم زر ماكارون           koolak
# ...

# %%
sorted_df8 = df.sort_values(by=['Gross_Profit_1', 'Gross_Profit_2', 'Gross_Profit_3'])
sorted_df8
# Out:
#      article                                            name type_promotion_1  \
# 10  10001886                       ماست 500 گرم پرچرب می ماس           koolak
# 20  10006126              ماست یونانی پر چرب 1500 گرم می ماس           koolak
# 32  10000632                      کرم کنجد ساده 350 گرم عقاب           koolak
# 4   10005607              ماست یونانی کم چرب 1500 گرم می ماس           koolak
# 34  10007174                              ارده 600 گرمی عقاب           koolak
# 12  10001337      ماكاروني فرمی پروانه اي   500 گ زر ماكارون           koolak
# 35  10003636                   ماست سبو پرچرب 1800 گرمی هراز           koolak
# 11  10001844                 شير كم چرب ساده  200 سي سي میهن           koolak
# 33  10002966                   دوغ  سنتی1/5 لیتری  پونه هراز           koolak
# 13  10006130                     شیر کم چرب 200 سی سی روزانه           koolak
# 30  10001320                     اسپاگتي  500 گرم زر ماكارون           koolak
# ...

# %%
#baraye inke be har sotoon rotbe bde va dar nahayat majmoo rotbe har satr ro bedast biari bayad injuri amal kni

# %%
import pandas as pd

# فرض کنید df داده‌فریم شما باشد

# افزودن ستون جدید به نام 'Total_Gross_Profit' با محاسبه مجموع دو ستون 'Gross_Profit_1' و 'Gross_Profit_2'
df['Total_Gross_Profit'] = df['Gross_Profit_1'] + df['Gross_Profit_2']

# نمایش نتیجه
df['Total_Gross_Profit']
# Out:
# 0     4.972883e+08
# 1     2.604360e+08
# 2     4.262760e+08
# 3     1.277432e+09
# 4     8.538330e+07
# 5     8.478992e+08
# 6     3.808610e+08
# 7     3.216932e+08
# 8     5.113675e+08
# 9     2.166328e+08
# 10    4.900815e+07
# 11    1.481128e+08
# 12    1.059758e+08
# 13    1.486241e+08
# 14    6.724559e+08
# 15    5.858275e+08
# 16    2.018238e+08
# 17    6.944574e+08
# 18    2.313538e+08
# 19    6.205291e+08
# 20    6.939011e+07
# 21    2.735419e+08
# 22    4.192838e+09
# 23    1.171603e+09
# 24    1.081145e+09
# 25    5.517742e+08
# 26    9.080060e+08
# 27    8.212710e+08
# 28    3.927760e+08
# 29    3.116585e+08
# 30    1.977120e+08
# 31    1.821379e+08
# 32    8.441608e+07
# 33    1.823967e+08
# 34    1.080994e+08
# 35    1.784872e+08
# Name: Total_Gross_Profit, dtype: float64

# %%
df
# Out:
#      article                                            name type_promotion_1  \
# 0   10001881                             بستني بيسکورول ميهن           koolak
# 1   10001874                         دوغ ساده  1500گرمی میهن           koolak
# 2   10001869                        دوغ نعناع  1500گرمی میهن           koolak
# 3   10003939  پنير سفيد نسبتا چرب ايراني دی 3 400 گرمي  میهن           koolak
# 4   10005607              ماست یونانی کم چرب 1500 گرم می ماس           koolak
# 5   10005610                         پنیر یواف 400 گرمی صباح           koolak
# 6   10003113                              کارنیتا وانیل میهن           koolak
# 7   10001883                        بستني کارنيتا شکلات ميهن           koolak
# 8   10001863                      شیر کاکائو  200 سی سی میهن           koolak
# 9   10004219                           پنیر گاو خندان روزانه           koolak
# 10  10001886                       ماست 500 گرم پرچرب می ماس           koolak
# ...

# %%
sorted_df8 = df.sort_values(by=['Gross_Profit_1', 'Gross_Profit_2', 'Gross_Profit_3'])

sorted_df8['Total_Gross_Profit'] = sorted_df8['Gross_Profit_1'] + sorted_df8['Gross_Profit_2']+sorted_df8['Gross_Profit_3']

sorted_df8['Total_Gross_Profit']
# Out:
# 10    9.289569e+07
# 20    1.147570e+08
# 32    1.306937e+08
# 4     1.310943e+08
# 34    1.755692e+08
# 12    1.482747e+08
# 35    2.822368e+08
# 11    2.376641e+08
# 33    3.100714e+08
# 13    2.243060e+08
# 30    3.077098e+08
# 16    3.001591e+08
# 9     2.953694e+08
# 18    3.148869e+08
# 31    3.101297e+08
# 1     3.747735e+08
# 21    3.884342e+08
# 7     4.593084e+08
# 29    3.575169e+08
# 6     5.313974e+08
# 8     8.424303e+08
# 28    5.180409e+08
# 2     6.063630e+08
# 0     7.188259e+08
# 25    7.573841e+08
# 26    1.477458e+09
# 15    8.603130e+08
# 19    8.947688e+08
# 17    9.821490e+08
# 14    1.010757e+09
# 27    1.154093e+09
# 5     1.121428e+09
# 24    1.585698e+09
# 23    1.704450e+09
# 3     1.771465e+09
# 22    6.219140e+09
# Name: Total_Gross_Profit, dtype: float64

# %%
#اگر بخواهیم دو ستون از یک دیتا فریم رو با هم ببینیم باید چکار کنیم؟

# %%
#import pandas as pd

# فرض کنید df داده‌فریم شما باشد

# روش 1: استفاده از متد [[]]
#selected_columns_1 = df[['Gross_Profit_1', 'Gross_Profit_2']]

# روش 2: استفاده از متد .loc
#selected_columns_2 = df.loc[:, ['Gross_Profit_1', 'Gross_Profit_2']]

# روش 3: استفاده از متد .iloc با استفاده از ایندکس‌های ستون‌ها
#column1_index = df.columns.get_loc('Gross_Profit_1')
#column2_index = df.columns.get_loc('Gross_Profit_2')
#selected_columns_3 = df.iloc[:, [column1_index, column2_index]]

# نمایش نتایج
#print(selected_columns_1)
#print(selected_columns_2)
#print(selected_columns_3)

# %%
selected_columns_1 = sorted_df8[['name', 'Total_Gross_Profit']]
selected_columns_1
# Out:
#                                               name  Total_Gross_Profit
# 10                       ماست 500 گرم پرچرب می ماس        9.289569e+07
# 20              ماست یونانی پر چرب 1500 گرم می ماس        1.147570e+08
# 32                      کرم کنجد ساده 350 گرم عقاب        1.306937e+08
# 4               ماست یونانی کم چرب 1500 گرم می ماس        1.310943e+08
# 34                              ارده 600 گرمی عقاب        1.755692e+08
# 12      ماكاروني فرمی پروانه اي   500 گ زر ماكارون        1.482747e+08
# 35                   ماست سبو پرچرب 1800 گرمی هراز        2.822368e+08
# 11                 شير كم چرب ساده  200 سي سي میهن        2.376641e+08
# 33                   دوغ  سنتی1/5 لیتری  پونه هراز        3.100714e+08
# 13                     شیر کم چرب 200 سی سی روزانه        2.243060e+08
# 30                     اسپاگتي  500 گرم زر ماكارون        3.077098e+08
# 16                      شیر پرچرب 200 سی سی روزانه        3.001591e+08
# ...

# %%
sorted_df8 = df.sort_values(by=['Gross_Profit_1', 'Gross_Profit_2', 'Gross_Profit_3'])

sorted_df8['Total_Gross_Profit'] = sorted_df8['Gross_Profit_1'] + sorted_df8['Gross_Profit_2']+sorted_df8['Gross_Profit_3']+sorted_df8['Gross_Profit_4']

sorted_df8['Total_Gross_Profit']

selected_columns_2 = sorted_df8[['name', 'Total_Gross_Profit']]
selected_columns_2
# Out:
# 10    1.089812e+08
# 20    1.344362e+08
# 32    1.885478e+08
# 4     1.560398e+08
# 34    2.662190e+08
# 12    2.173363e+08
# 35    4.940535e+08
# 11    3.909795e+08
# 33    4.485149e+08
# 13    3.157991e+08
# 30    4.470018e+08
# 16    4.129765e+08
# 9     3.565694e+08
# 18    3.851971e+08
# 31    4.528265e+08
# 1     4.508408e+08
# 21    5.013675e+08
# 7     5.075054e+08
# 29    5.512321e+08
# 6     5.889853e+08
# 8     1.249013e+09
# 28    6.327819e+08
# 2     7.365986e+08
# 0     8.977358e+08
# 25    1.001580e+09
# 26    1.777594e+09
# 15    1.158612e+09
# 19    1.283506e+09
# 17    1.207581e+09
# 14    1.419323e+09
# 27    1.463434e+09
# 5     1.328245e+09
# 24    1.973949e+09
# 23    2.098546e+09
# 3     2.112322e+09
# 22    7.745343e+09
# Name: Total_Gross_Profit, dtype: float64
#                                               name  Total_Gross_Profit
# 10                       ماست 500 گرم پرچرب می ماس        1.089812e+08
# ...

# %%
df.columns
# Out:
# Index(['article', 'name', 'type_promotion_1', 'discount_koolak_1', 'Sale_NO_1',
#        'Sale_RR_1', 'Margin_1', 'Gross_Profit_1', 'type_promotion_2',
#        'discount_jarchi_2', 'Sale_NO_2', 'Sale_RR_2', 'Margin_2',
#        'Gross_Profit_2', 'type_promotion_3', 'discount_jarchi_3', 'Sale_No_3',
#        'Sale_RR_3', 'Margin_3', 'Gross_Profit_3', 'type_promotion_4',
#        'discount_jarchi_4', 'Sale_NO_4', 'Sale_RR_4', 'Margin_4',
#        'Gross_Profit_4', 'koolak_1_hafte', 'koolak_1_month', 'jarchi_2_hafte',
#        'jarchi_2_month', 'jarchi_3_hafte', 'jarchi_3_month', 'jarchi_4_hafte',
#        'jarchi_4_month', 'Length_Range', 'Total_Gross_Profit'],
#       dtype='object')

# %%
sorted_df8 = df.sort_values(by=['Gross_Profit_1', 'Gross_Profit_2', 'Gross_Profit_3','Gross_Profit_4','koolak_1_hafte','jarchi_2_hafte','jarchi_3_hafte','jarchi_4_hafte'])

sorted_df8['Total_Gross_Profit'] = sorted_df8['Gross_Profit_1'] + sorted_df8['Gross_Profit_2']+sorted_df8['Gross_Profit_3']+sorted_df8['Gross_Profit_4']+sorted_df8['koolak_1_hafte']+sorted_df8['jarchi_2_hafte']+sorted_df8['jarchi_3_hafte']+sorted_df8['jarchi_4_hafte']

sorted_df8['Total_Gross_Profit']

selected_columns_3 = sorted_df8[['name', 'Total_Gross_Profit']]
selected_columns_3
# Out:
# 10    1.089812e+08
# 20    1.344362e+08
# 32    1.885478e+08
# 4     1.560398e+08
# 34    2.662190e+08
# 12    2.173363e+08
# 35    4.940535e+08
# 11    3.909795e+08
# 33    4.485149e+08
# 13    3.157991e+08
# 30    4.470018e+08
# 16    4.129765e+08
# 9     3.565694e+08
# 18    3.851971e+08
# 31    4.528265e+08
# 1     4.508408e+08
# 21    5.013675e+08
# 7     5.075054e+08
# 29    5.512321e+08
# 6     5.889853e+08
# 8     1.249013e+09
# 28    6.327819e+08
# 2     7.365986e+08
# 0     8.977358e+08
# 25    1.001580e+09
# 26    1.777594e+09
# 15    1.158612e+09
# 19    1.283506e+09
# 17    1.207581e+09
# 14    1.419323e+09
# 27    1.463434e+09
# 5     1.328245e+09
# 24    1.973949e+09
# 23    2.098546e+09
# 3     2.112322e+09
# 22    7.745343e+09
# Name: Total_Gross_Profit, dtype: float64
#                                               name  Total_Gross_Profit
# 10                       ماست 500 گرم پرچرب می ماس        1.089812e+08
# ...

# %%
sorted_df8 = df.sort_values(by=['Gross_Profit_1', 'Gross_Profit_2', 'Gross_Profit_3','Gross_Profit_4', 'koolak_1_hafte','jarchi_2_hafte','jarchi_3_hafte','jarchi_4_hafte','koolak_1_month','jarchi_2_month','jarchi_3_month','jarchi_4_month'])

sorted_df8['Total_Rank'] = sorted_df8['Gross_Profit_1'] + sorted_df8['Gross_Profit_2']+sorted_df8['Gross_Profit_3']+sorted_df8['Gross_Profit_4']+sorted_df8['koolak_1_hafte']+sorted_df8['jarchi_2_hafte']+sorted_df8['jarchi_3_hafte']+sorted_df8['jarchi_4_hafte']+sorted_df8['koolak_1_month']+sorted_df8['jarchi_2_month']+sorted_df8['jarchi_3_month']+sorted_df8['jarchi_4_month']

sorted_df8['Total_Rank']

selected_columns_4 = sorted_df8[['name', 'Total_Rank']]
selected_columns_4
# Out:
# 10    1.089812e+08
# 20    1.344362e+08
# 32    1.885478e+08
# 4     1.560398e+08
# 34    2.662190e+08
# 12    2.173363e+08
# 35    4.940535e+08
# 11    3.909795e+08
# 33    4.485149e+08
# 13    3.157991e+08
# 30    4.470018e+08
# 16    4.129765e+08
# 9     3.565694e+08
# 18    3.851971e+08
# 31    4.528265e+08
# 1     4.508408e+08
# 21    5.013675e+08
# 7     5.075054e+08
# 29    5.512321e+08
# 6     5.889853e+08
# 8     1.249013e+09
# 28    6.327819e+08
# 2     7.365986e+08
# 0     8.977358e+08
# 25    1.001580e+09
# 26    1.777594e+09
# 15    1.158612e+09
# 19    1.283506e+09
# 17    1.207581e+09
# 14    1.419323e+09
# 27    1.463434e+09
# 5     1.328245e+09
# 24    1.973949e+09
# 23    2.098546e+09
# 3     2.112322e+09
# 22    7.745343e+09
# Name: Total_Rank, dtype: float64
#                                               name    Total_Rank
# 10                       ماست 500 گرم پرچرب می ماس  1.089812e+08
# 20              ماست یونانی پر چرب 1500 گرم می ماس  1.344362e+08
# ...

# %%
sorted_df8 = df.sort_values(by=['Gross_Profit_1', 'Gross_Profit_2', 'Gross_Profit_3','Gross_Profit_4'])

sorted_df8['Total_Gross_Profit'] = sorted_df8['Gross_Profit_1'] + sorted_df8['Gross_Profit_2']+sorted_df8['Gross_Profit_3']+sorted_df8['Gross_Profit_4']

sorted_df8['Total_Gross_Profit']

selected_columns_5 = sorted_df8[['name', 'Total_Gross_Profit']]
selected_columns_5
# Out:
# 10    1.089812e+08
# 20    1.344362e+08
# 32    1.885478e+08
# 4     1.560398e+08
# 34    2.662190e+08
# 12    2.173363e+08
# 35    4.940535e+08
# 11    3.909795e+08
# 33    4.485149e+08
# 13    3.157991e+08
# 30    4.470018e+08
# 16    4.129765e+08
# 9     3.565694e+08
# 18    3.851971e+08
# 31    4.528265e+08
# 1     4.508408e+08
# 21    5.013675e+08
# 7     5.075054e+08
# 29    5.512321e+08
# 6     5.889853e+08
# 8     1.249013e+09
# 28    6.327819e+08
# 2     7.365986e+08
# 0     8.977358e+08
# 25    1.001580e+09
# 26    1.777594e+09
# 15    1.158612e+09
# 19    1.283506e+09
# 17    1.207581e+09
# 14    1.419323e+09
# 27    1.463434e+09
# 5     1.328245e+09
# 24    1.973949e+09
# 23    2.098546e+09
# 3     2.112322e+09
# 22    7.745343e+09
# Name: Total_Gross_Profit, dtype: float64
#                                               name  Total_Gross_Profit
# 10                       ماست 500 گرم پرچرب می ماس        1.089812e+08
# ...

# %%
selected_columns_5.to_excel('output.xlsx', index=False)

# %%
# ساخت یک DataFrame نمونه
#data = {'Column1': [1, 2, 3],
        #'Column2': ['A', 'B', 'C']}
#df = pd.DataFrame(data)

# ذخیره داده‌ها در یک فایل اکسل
#df.to_excel('output.xlsx', index=False)

#طبق اصلاحیه ای که انجام شد نمیشود با نوشتن این که ماکس این ستون را بدست بیاور سورت شده هر ستون رو بهش رنک داد و با هم جمع کرد
#و باید از
#df.sort_values
# استفاده کرد و هر ستون رو رنک بندی کنیم و بعد رنک ها رو با هم جمع کرد
#import pandas as pd

# فرض کنید df داده‌فریم شما باشد



# افزودن ستون جدید به نام 'Total_Gross_Profit' با محاسبه مجموع دو ستون 'Gross_Profit_1' و 'Gross_Profit_2'
#df['Total_Gross_Profit'] = df['Gross_Profit_1'] + df['Gross_Profit_2']

# نمایش نتیجه
#print(df)
